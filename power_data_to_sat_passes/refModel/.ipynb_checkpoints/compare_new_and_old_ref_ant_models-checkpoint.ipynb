# %%
new = genfromtxt('new_ref_dipole_model_137_31july2015+el.txt')

# %%
new.shape
# Out:
# (32400, 8)

# %%
scatter(sin(pi/180.*new[:,0])*sin(pi/180.*new[:,1]),sin(pi/180.*new[:,0])*cos(pi/180.*new[:,1]),10,new[:,2],edgecolor='none',vmin=-15,vmax=0)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10c1f8d88>

# %%
old = genfromtxt('ff137_0_xpol+el.txt')

# %%
scatter(sin(pi/180.*old[:,0])*sin(pi/180.*old[:,1]),sin(pi/180.*old[:,0])*cos(pi/180.*old[:,1]),10,old[:,2]-max(old[:,2]),edgecolor='none',vmin=-15,vmax=0)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10c095368>

# %%
scatter(sin(pi/180.*old[:,0])*sin(pi/180.*old[:,1]),sin(pi/180.*old[:,0])*cos(pi/180.*old[:,1]),10,new[:,2]-max(new[:,2])-(old[:,2]-max(old[:,2])),edgecolor='none',vmin=-4,vmax=4)
colorbar()
title('(new / old) reference antenna model (dB)')
